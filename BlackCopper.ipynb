# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
fi=pd.read_excel(r"C:\Users\acer\Downloads\Input.xlsx")
fi.head()
#print(fi)
a=[]
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36'}
for i in fi["URL"]:
    #print(i)
    #url="https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/"
#     url=input.iloc[i+1,1:]
    r=requests.get(i,headers=headers)
    htmlcontent=r.content
#print(htmlcontent)
    soup=BeautifulSoup(htmlcontent,'html.parser')
#print(soup)
#print(soup.prettify)
    body=soup.find('body')
#print((body.string))
    para=soup.find_all('p')
    #print(para)
    a.append(para)
    #i["Body"] = para
# print(a)
# fi.head()

# %%
fi["Body"]=a

# %%
fi.head(30)
# Out:
#     URL_ID                                                URL  \
# 0     37.0  https://insights.blackcoffer.com/ai-in-healthc...
# 1     38.0  https://insights.blackcoffer.com/what-if-the-c...
# 2     39.0  https://insights.blackcoffer.com/what-jobs-wil...
# 3     40.0  https://insights.blackcoffer.com/will-machine-...
# 4     41.0  https://insights.blackcoffer.com/will-ai-repla...
# 5     42.0  https://insights.blackcoffer.com/man-and-machi...
# 6     43.0  https://insights.blackcoffer.com/in-future-or-...
# 7     44.0  https://insights.blackcoffer.com/how-neural-ne...
# 8     45.0  https://insights.blackcoffer.com/how-machine-l...
# 9     46.0  https://insights.blackcoffer.com/deep-learning...
# 10    47.0  https://insights.blackcoffer.com/how-to-protec...
# 11    48.0  https://insights.blackcoffer.com/how-machines-...
# 12    49.0  https://insights.blackcoffer.com/ai-human-robo...
# 13    50.0  https://insights.blackcoffer.com/how-ai-will-c...
# 14    51.0  https://insights.blackcoffer.com/future-of-wor...
# 15    52.0  https://insights.blackcoffer.com/ai-tool-alexa...
# 16    53.0  https://insights.blackcoffer.com/ai-healthcare...
# 17    54.0  https://insights.blackcoffer.com/all-you-need-...
# 18    55.0  https://insights.blackcoffer.com/evolution-of-...
# 19    56.0  https://insights.blackcoffer.com/how-data-anal...
# 20    57.0  https://insights.blackcoffer.com/covid-19-envi...
# 21    58.0  https://insights.blackcoffer.com/environmental...
# 22    59.0  https://insights.blackcoffer.com/how-data-anal...
# 23    60.0  https://insights.blackcoffer.com/difference-be...
# 24    61.0  https://insights.blackcoffer.com/how-python-be...
# 25    62.0  https://insights.blackcoffer.com/how-google-fi...
# 26    63.0  https://insights.blackcoffer.com/what-is-the-f...
# 27    64.0  https://insights.blackcoffer.com/impact-of-ai-...
# 28    65.0  https://insights.blackcoffer.com/telemedicine-...
# 29    66.0  https://insights.blackcoffer.com/how-we-foreca...
#
#                                                  Body
# 0   [[[Introduction]], [“If anything kills over 10...
# 1   [[Human minds, a fascination in itself carryin...
# 2   [[[Introduction]], [AI is rapidly evolving in ...
# 3   [[“Anything that could give rise to smarter-th...
# 4   [[“Machine intelligence is the last invention ...
# 5   [[Where is this disruptive technology taking u...
# 6   [[In future or in upcoming years humans and ma...
# 7                                                  []
# 8   [[Machine learning techniques may have been us...
# 9   [[eLearning as technology becomes more afforda...
# 10  [[Before the internet, information was in some...
# 11  [[We all hear day in and day out that we amids...
# 12  [[It’s the year 2060. An automaton in a Resear...
# 13  [[The way work is being done now is destined t...
# 14  [[Artificial intelligence and employment are t...
# 15  [[Through AI tools like natural language proce...
# 16  [[AI experts believe it’s going to be one of t...
# 17  [[ ], [ ], [[]], [[Ever wondered how you get n...
# 18  [[[Advertising can be described as a type of s...
# 19  [[Before we get into the whole discussion, let...
# 20                                                 []
# 21  [[The Covid- 19 pandemics forced factories to ...
# 22  [[Even though COVID-19 has not yet halted and ...
# 23  [[“Data is the new oil” has become the most im...
# 24  [[Data Science is gaining popularity exponenti...
# 25  [[It was in March that Tech giant Google came ...
# 26  [[From what I have learned on the mobile apps ...
# 27  [[AI allows those in training to go through na...
# 28  [[In today’s world, telemedicine technology is...
# 29  [[TECHNOLOGY is playing a dominant role in hum...

# %%
# url=fi.iloc[3,1:]
# print(url)
# (input.size)/2
# input.describe
# input.shape
# input.dtypes
# for i in input.size:
#     print(i)

# %%
fi.to_excel("output.xlsx")
